# %%
import os
import json
import tkinter as tk
from tkinter import filedialog
import time
import concurrent.futures
import threading
import subprocess
import re

def extract_working_directory(netj_file):
    try:
        with open(netj_file, 'r') as file:
            data = json.load(file)
            return data.get('work_dir', '')
    except Exception as e:
        print(f"Error extracting working directory from {netj_file}: {str(e)}")
        return None

def monitor_and_update_active_file(working_directory, sormax, maxit):
    target_file = os.path.join(working_directory, "ACTIVE")
    while not os.path.exists(target_file):
        print(f"Waiting for Active file in {working_directory}...")
        time.sleep(10)
    time.sleep(15)
    print(f"Active file found in {working_directory}. Starting monitoring and updating...")

    # Monitor and update logic here
    with open(target_file, "r") as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        if "SORMAX" in line and "MAXIT" in line:
            names = line.split('!')[-1].strip().split(',')
            print(names)
            print(line)
            if "SORMAX" in names and "MAXIT" in names:

                splits = [0, 11, 18, 25, 35]
                values = [line[splits[i]:splits[i+1]] for i in range(len(splits)-1)]
                values = [x.strip() for x in values]
                print(values)
                sormax_index = names.index('SORMAX')
                maxit_index = names.index('MAXIT')
                values[sormax_index] = format(float(sormax), '.4f')
                values[maxit_index] = maxit
                print(values)

                formatted_line = "     {:}     {:}   {:}      {:}   !{}".format(values[0], values[1], values [2], values[3], ','.join(names))
                lines[i] = formatted_line + '\n'

    with open(target_file, "w") as f:
        f.writelines(lines)

    print(f"Active file updated and monitoring completed in {working_directory}. Exiting monitoring.")
    return

def run_simulation(netj_file, sormax, maxit):
    regex = "\d{4}"
    netj_num = re.findall(regex, netj_file)[1]
    if not (working_directory := extract_working_directory(netj_file)):
        return
    os.chdir(working_directory)
    cfd_time_file = os.path.join(working_directory, 'CFD_TIME')

    if not os.path.exists(cfd_time_file):
        with open(cfd_time_file, 'w') as f:
            f.write('0')

    print(f"Running simulation for {netj_file} in {working_directory}")

    rainbow_dir = os.path.join(os.getenv('localappdata'), 'Programs', 'ReactionEngineeringInternational', 'CFS-EPA', 'cowtip', 'x64', 'Release',)
    os.chdir(rainbow_dir)

    # Run RainbowBatch.exe with the .NETJ file as an argument
    # process = subprocess.Popen(['RainbowBatch.exe', netj_file])
    with subprocess.Popen(['RainbowBatch.exe', netj_file], stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text = 'TRUE') as process:
        for line in iter(process.stdout.readline, ''):
            print(netj_num, ':', line, end='')
        return_code = process.wait()
        if return_code != 0:
            print(f"RainbowBatch.exe {netj_file} failed with return code {return_code}.")

    #Monitor for the presence of reks35.out
    while True:
        if os.path.exists(os.path.join(working_directory, 'streamline_pp.vtk')):
            time.sleep(30)
            process.terminate()
            process.wait()

            # print('Simulation completed.')
            return
        else:
            time.sleep(10)

def run_sim_and_monitor(netj_file, sormax, maxit):
    # Create a thread for running the simulation
    sim_thread = threading.Thread(target=run_simulation, args=(netj_file, sormax, maxit))
    monitor_thread = threading.Thread(target=monitor_and_update_active_file, args=(extract_working_directory(netj_file), sormax, maxit))

    # Start the simulation thread
    sim_thread.start()
    monitor_thread.start()
    
    # Wait for the simulation thread to finish
    sim_thread.join()
    monitor_thread.join()
    # print('sim and monitor threads joined')

def main():
    root = tk.Tk()
    root.withdraw()

    netj_files = filedialog.askopenfilenames(
        title="Select .NETJ files",
        filetypes=[("NETJ Files", "*.netj")],
        initialdir='C:/Users/KWILKES/Desktop/PFAS_Modeling/cfs_para_test_cond/0000_docs',
        multiple=True
    )

    sormax = input("Please enter a value for SORMAX (default: 2.5): ") or "2.5"
    maxit = input("Please enter a value for MAXIT (default: 500): ") or "500"

    max_concurrent_processes = 4

    with concurrent.futures.ThreadPoolExecutor(max_concurrent_processes) as executor:
        futures = []
        for netj_file in netj_files:
            # Remove ACTIVE file if it exists
            working_directory = extract_working_directory(netj_file)
            active_file = os.path.join(working_directory, "ACTIVE")
            if os.path.exists(active_file):
                os.remove(active_file)
                
            # Use the new wrapper function to ensure both simulation and monitoring are run together
            future = executor.submit(run_sim_and_monitor, netj_file, sormax, maxit)
            futures.append(future)
            # print('futures appended')
        concurrent.futures.wait(futures)
        # print('concurrent futures wait done')

    print("All simulations and monitoring/updating completed.")
    root.destroy()
if __name__ == "__main__":
    main()
# Out:
# Waiting for Active file in C:\Users\KWILKES\Desktop\PFAS_Modeling\cfs_para_test_cond\001_1stream\1120_41kW_CF4_port1...
# Running simulation for C:/Users/KWILKES/Desktop/PFAS_Modeling/cfs_para_test_cond/001_1stream/0000_docs/1120_rainbow_41kW_CF4_port1.netj in C:\Users\KWILKES\Desktop\PFAS_Modeling\cfs_para_test_cond\001_1stream\1120_41kW_CF4_port1
# 1120 : loading document C:/Users/KWILKES/Desktop/PFAS_Modeling/cfs_para_test_cond/001_1stream/0000_docs/1120_rainbow_41kW_CF4_port1.netj...
# 1120 : loading json-type net file C:/Users/KWILKES/Desktop/PFAS_Modeling/cfs_para_test_cond/001_1stream/0000_docs/1120_rainbow_41kW_CF4_port1.netj
# 1120 : executing...
# 1120 :  IPAS      5936800
# 1120 :          122          93          65
# 1120 :  BEWARE OF SOME CHANGE IN DATA FILE !!
# 1120 :  CHECK SUBROUTINE SETUP TO MAKE SURE YOU GOT
# 1120 :  RIGHT DATA FILE FORMAT!!!
# 1120 :
# 1120 :       <<EPA Lab Kiln primary chamber>>
# 1120 :
# 1120 :                      Simulation date:   1/ 1/ 1
# 1120 :    f=1 stream: Temp. =  298.1K, Density =  0.682kg/m3, Enthalpy = -4.668E+06 J/Kg
# 1120 :    f=0 stream: Temp. =  335.9K, Density =  1.042kg/m3, Enthalpy = -5.831E+04 J/Kg
# 1120 :  eta=1 stream: Temp. =  755.0K, Density =  0.451kg/m3, converged = T
# 1120 :  eta=1 stream: Enthalpy =-3.161E+06 J/Kg
# 1120 :  NSTROIL,NSTEAM, IDOILG,IDOILL,IDSLLQ:
# 1120 :            0           0           0          26           0
# 1120 :  prim. stream: Temp. =  298.2K, Density =  0.656kg/m3, converged = T
# 1120 :   sec. stream: Temp. =  335.9K, Density =  1.042kg/m3, converged = T
# 1120 :          121          92          41         122          93          65
# 1120 :  BEGIN TO READ IPLANE
# 1120 :  DONE READING GRID
# 1120 :
# 1120 :
# 1120 :                 Geometry input file read successfully
# 1120 :   cell type count
# 1120 :     type            total         active
# 1120 :     primary             21
# 1120 :     secondary           76
# 1120 :     tertiary             0
# 1120 :     decomp               0
# 1120 :     ffield           85131
# 1120 :     wall            371184
# 1120 :     symmetry             0
# 1120 :     total           456412
# 1120 :      ni*nj*nk       456412
# 1120 :
# 1120 :     walls with a wet surface         14260
# 1120 :
# 1120 :
# 1120 :                           _________________________
# 1120 :                          /                        /|
# 1120 :                         /                        / |
# 1120 :                        /                        /  |
# 1120 :                       /               NK =  41 /   |
# 1120 :                      /________________________/    |
# 1120 :                     |                        |     |
# 1120 :                     |                        |     |
# 1120 :                     |                        |     |
# 1120 :                     |                        |    /
# 1120 :                     |                        |   / NI = 121
# 1120 :                     |                        |  /
# 1120 :                     |                        | /
# 1120 :                     |________________________|/
# 1120 :              NJ =  92
# 1120 :
# 1120 :   sucessfully read restrt file
# 1120 :  into AREAIN
# 1120 :   areain: primary  :total,bdry/ext:   0.2168E-02  0.2168E-02  0.0000E+00
# 1120 :   areain: secondary:total,bdry/ext:   0.9464E-02  0.9464E-02  0.0000E+00
# 1120 :  out of AREAIN
# 1120 :  into PROFIN
# 1120 :   ** PROFIN routine now reads in temperatures **
# 1120 :   **  PRPDF does not overwrite these values,  **
# 1120 :   **  but other property options may - check  **
# 1120 :   ** them if you are using a different option **
# 1120 :  INLET CELL NUMBER FROM INLET :           97
# 1120 :  INLET CELL NUMBER FROM GRID :           97
# 1120 :  INLET FILE IS GOOD!
# 1120 :  before ext: Primary Flow :   1.5090527E-03  kg/s
# 1120 :  before ext: Secondary Flow :   9.8620541E-03  kg/s
# 1120 :        Primary Flow reset to:   1.5090527E-03  kg/s
# 1120 :      Secondary Flow reset to:   9.8620541E-03  kg/s
# 1120 :     Inlet Mixture f reset to:   0.0000000E+00
# 1120 :   Inlet Mixture eta reset to:   0.0000000E+00
# 1120 :           Primary Inlet Area:   2.1677376E-03  m^2
# 1120 :         Secondary Inlet Area:   9.4636874E-03  m^2
# 1120 :  out of PROFIN
# 1120 :  into PROFT
# 1120 :  out of PROFT
# 1120 :  into PROFP
# 1120 :  out of PROFP
# 1120 :  into RDOM0
# 1120 :  out of RDOM0
# 1120 :                   Wall Model:  Specified RW and T in .wbc
# 1120 :                   Wall Model:  Fixed backside temperature
# 1120 :   enter psict0
# 1120 :  Reading lrdisl,lrdips,lwrxn,lsorb in DATA file ...
# 1120 :  read them
# 1120 :  nsl,nps,ipplot,ipsoil           1           1          10           1
# 1120 :  COAL COMBUSTION ONLY
# 1120 :  isl           1
# 1120 :  xps,yps,zps read
# 1120 :  pw,sigmas read
# 1120 :  uplags read
# 1120 :  tlags read
# 1120 :  iend before pd read           1
# 1120 :  isl,pd`s read           1
# 1120 :
# 1120 :      Particle diameters:
# 1120 :         ips,pd0(ips)    1   0.216000E-04
# 1120 :
# 1120 :
# 1120 :  before pmf read
# 1120 :  F
# 1120 : FLOWS 0 0
# 1120 :  PW_GROUP   1.0326714E-10
# 1120 :  PW_GROUP   9.9999997E-06
# 1120 :  PW_GROUP   9.9999997E-06
# 1120 :  PW_GROUP   9.9999997E-06
# 1120 :  PW_GROUP   9.9999997E-06
# 1120 :  PW_GROUP   9.9999997E-06
# 1120 :  CFAC_GROUP            1  1.5742424E-08           1
# 1120 :  PW            1           1   1.000000      1.0326714E-10
# 1120 :  maxitp,minitp,maxstp,mxrcrc,isourc =          100           2        1000
# 1120 :          200         -10
# 1120 :  stick,tstick,cr,cf =   1.000000       273.0000      0.0000000E+00
# 1120 :   0.0000000E+00
# 1120 :  rkp,rkg,aks =    1.700000      7.0000000E-02  0.1000000
# 1120 :      total coal =    0.103267E-09 kg/s
# 1120 :      primary gas =   0.150905E-02 kg/s
# 1120 :      secondary gas =   0.986205E-02 kg/s
# 1120 :      Tertiary gas =   0.000000E+00 kg/s
# 1120 :
# 1120 :      total gas  =    0.113711E-01 kg/s
# 1120 :
# 1120 :             Particle Loading:   9.0815382E-09
# 1120 :  out of psict0
# 1120 :   enter coal0
# 1120 :  jend =            1
# 1120 :  thetac, nfrag =   0.7000000               4
# 1120 :  reading info for particle type            1
# 1120 :  ready to read pdens
# 1120 :  read j, pdens,xi,gammaa =            1   2000.000       1.000000
# 1120 :   0.1000000
# 1120 :  read hco
# 1120 :  read hw0
# 1120 :  read omegas
# 1120 :  read omegas
# 1120 :  reading coal rates
# 1120 :  reading char rates
# 1120 :  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1120 :   UNIT OF THE OXIDATION PARAMETERS
# 1120 :   REQUIRED UNIT FOR A : kg C / (m2-sec-(PaO2)n)
# 1120 :     n is reaction order (rxnord)
# 1120 :   REQUIRED UNIT E :  J / kmol
# 1120 :  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1120 :  reading wics
# 1120 :  done with wics
# 1120 :   wics   0.5704000      0.1005000      0.2189000      0.0000000E+00
# 1120 :   9.9999998E-03  0.0000000E+00  0.1002000      0.0000000E+00
# 1120 :
# 1120 :  Particle flow rate is  1.0326714E-10 kg/s
# 1120 : F-->C ========================================
# 1120 : 1.03267e-10 = Coal flow 0
# 1120 : 1e-05 = Coal flow 1
# 1120 : 1e-05 = Coal flow 2
# 1120 : 1e-05 = Coal flow 3
# 1120 : 1e-05 = Coal flow 4
# 1120 : 1e-05 = Coal flow 5
# 1120 : F-->C ========================================
# 1120 : HC0 1.39097e+06 47.4938 99.7123 0.311915 0 5.27413 -8389.1 1 -94.05 -68.32 -71 -22.06 -64.79
# 1120 :  omegal   0.9683523      omegaa  3.1647719E-02
# 1120 :  FRAC_ETA   0.2668061
# 1120 :  OMEGAL OMEGAA OMEGAC   0.9683523      3.1647719E-02  2.2351742E-08
# 1120 :  HPIN =  0.0000000E+00  J/s
# 1120 :
# 1120 :  j,hp0(j)           1  -475981.7
# 1120 :
# 1120 :  HP0T =    1390970.      J/Kg
# 1120 :      Boil pnt for water @ pressure (K):       0.000
# 1120 :      Boil pnt for oil @ pressure (K):       0.000
# 1120 :  out of coal0
# 1120 :  lrdpr  T  lcoal  T  lcfden            0  lcalet  T
# 1120 :   ** PROFIN routine now reads in temperatures **
# 1120 :   **  PRPDF does not overwrite these values,  **
# 1120 :   **  but other property options may - check  **
# 1120 :   ** them if you are using a different option **
# 1120 :  INLET CELL NUMBER FROM INLET :           97
# 1120 :  INLET CELL NUMBER FROM GRID :           97
# 1120 :  INLET FILE IS GOOD!
# 1120 :  before ext: Primary Flow :   1.4221997E-03  kg/s
# 1120 :  before ext: Secondary Flow :   1.1044196E-02  kg/s
# 1120 :        Primary Flow reset to:   1.4221997E-03  kg/s
# 1120 :      Secondary Flow reset to:   1.1044196E-02  kg/s
# 1120 :     Inlet Mixture f reset to:   0.1140827
# 1120 :   Inlet Mixture eta reset to:   0.0000000E+00
# 1120 :    Primary enthalpy reset to:   -4668361.      J/kg
# 1120 :  Secondary enthalpy reset to:   -94926.85      J/kg
# 1120 :           Primary Inlet Area:   2.1677376E-03  m^2
# 1120 :         Secondary Inlet Area:   9.4636874E-03  m^2
# 1120 :   ** PROFIN routine now reads in temperatures **
# 1120 :   **  PRPDF does not overwrite these values,  **
# 1120 :   **  but other property options may - check  **
# 1120 :   ** them if you are using a different option **
# 1120 :  INLET CELL NUMBER FROM INLET :           97
# 1120 :  INLET CELL NUMBER FROM GRID :           97
# 1120 :  INLET FILE IS GOOD!
# 1120 :  before ext: Primary Flow :   7.4073602E-04  kg/s
# 1120 :  before ext: Secondary Flow :   1.7959937E-02  kg/s
# 1120 :        Primary Flow reset to:   7.4073602E-04  kg/s
# 1120 :      Secondary Flow reset to:   1.7959937E-02  kg/s
# 1120 :     Inlet Mixture f reset to:   3.9610125E-02
# 1120 :   Inlet Mixture eta reset to:   0.0000000E+00
# 1120 :    Primary enthalpy reset to:   -4668360.      J/kg
# 1120 :  Secondary enthalpy reset to:   -94926.84      J/kg
# 1120 :           Primary Inlet Area:   2.1677376E-03  m^2
# 1120 :         Secondary Inlet Area:   9.4636874E-03  m^2
# 1120 :      particle loading =    0.908154E-08 kg/s
# 1120 :      primary gas =   0.740736E-03 kg/s
# 1120 :      secondary gas =   0.179599E-01 kg/s
# 1120 :      Tertiary gas =   0.000000E+00 kg/s
# 1120 :
# 1120 :      total gas  =    0.187007E-01 kg/s
# 1120 :
# 1120 :  initialization for lfsou true
# 1120 :   TSPM, SSPM =  0.0000000E+00  0.0000000E+00
# 1120 :  SSPMsg   1.7959900E-02  SSPMEsg   0.0000000E+00  SSPMCHIsg   0.0000000E+00
# 1120 :  into BCIN
# 1120 :  bcin: before extru
# 1120 :  BCIN:FLOWIN,TKEIN,TEDIN,ENTHIN,CHIIN,ETAIN,FMIXIN=  1.8700667E-02
# 1120 :   7.1543641E-04  1.7943049E-02  -5162.903      0.0000000E+00  0.0000000E+00
# 1120 :   7.4073597E-04
# 1120 :  bcin: after extru
# 1120 :  BCIN:FLOWIN,TKEIN,TEDIN,ENTHIN,CHIIN,ETAIN,FMIXIN=  3.6660567E-02
# 1120 :   1.9515149E-02  0.4894373      -140829.9      0.0000000E+00  0.0000000E+00
# 1120 :   2.0205252E-02
# 1120 :  out of BCIN
# 1120 :  into INVAR
# 1120 :       Global Reynolds Number:    1477.283
# 1120 :  out of INVAR
# 1120 :  into TABLE
# 1120 :  out of TABLE
# 1120 :  into props
# 1120 :  into props
# 1120 :  into RDOMR
# 1120 :  out of RDOMR
# 1120 :  into WALLPR
# 1120 :  out of WALLPR
# 1120 :               Radiation done: af = 0.2097 ( 9 iter), dtwmax =   0.00
# 1120 :              Wall Model done: dtw =  0.00 ( 1 iter)
# 1120 :           Restart files used:         yes
# 1120 :             Turbulence Model:  standard  k-e
# 1120 :  Resetting ipref,jpref,kpref to   2  17  18 for pressure initialization
# 1120 :      P Reference at I,J,K of:           2          17          18
# 1120 :  Adiabatic Flame Temperature:    1205.280
# 1120 :  Adiabatic Flame Temp (w/HL):    1213.624
# 1120 :    Overall Equivalence Ratio:   0.3731023      (fuel rich when er > 1.0)
# 1120 :    Approximate Thermal Input:    38008.12      watts (at current burnout)
# 1120 :   Apprx Thermal Input (w/HL):    38397.29      watts (at current burnout)
# 1120 :  into OUTPUT
# 1120 :  out of OUTPUT
# 1120 :
# 1120 :  NITER  RESMAX   RES__U   RES__V   RES__W   RES__P   RES__M   RESTKE   omb   nt
# 1120 :         CONV rst RESTED   RES__H   RES__F   RES__G   RESETA   RESGET   r_af  ir
# 1120 :   Starting up properties
# 1120 :  bcin: before extru
# 1120 :  BCIN:FLOWIN,TKEIN,TEDIN,ENTHIN,CHIIN,ETAIN,FMIXIN=  1.8700667E-02
# 1120 :   7.1543641E-04  1.7943049E-02  -5162.903      0.0000000E+00  0.0000000E+00
# 1120 :   7.4073597E-04
# 1120 :  bcin: after extru
# 1120 :  BCIN:FLOWIN,TKEIN,TEDIN,ENTHIN,CHIIN,ETAIN,FMIXIN=  3.6660567E-02
# 1120 :   1.9515149E-02  0.4894373      -140829.9      0.0000000E+00  0.0000000E+00
# 1120 :   2.0205252E-02
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6735654E-02  3.6660224E-02 -3.7126641E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.723E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :     1   7.00     3.18  2  2.79  2  2.59  2  1.50 10  2.81  8  0.96  2  1.97      7
# 1120 :         2.50 50  0.63  2  3.50  2  2.88  2  3.53  2  7.00  1  7.00  1  0.21   2
# 1120 :         Uave =   0.2381   Vave =   0.1176   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.8 K,  Outlet Mass Flow:  0.36676E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48524E-06 ppm      12.5161 %
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6736149E-02  3.6662281E-02 -3.7369940E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.720E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :     2   7.00     3.16  2  2.79  2  2.57  2  1.45 20  2.72  8  0.95  2  2.67      6
# 1120 :         2.50 50  0.60  2  3.47  2  2.87  2  3.39  2  7.00  1  7.00  1  0.21   3
# 1120 :         Uave =   0.2381   Vave =   0.1176   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36676E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48504E-06 ppm      12.5169 %
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6736585E-02  3.6662161E-02 -3.7583872E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.710E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :     3   7.00     3.15  2  2.78  2  2.56  2  1.44 20  2.63  8  0.95  2  2.64      8
# 1120 :         2.50 50  0.63  2  3.49  2  2.87  2  3.41  2  7.00  1  7.00  1  0.21   3
# 1120 :         Uave =   0.2380   Vave =   0.1176   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36676E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48489E-06 ppm      12.5178 %
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6737233E-02  3.6662359E-02 -3.7902591E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.701E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :     4   7.00     3.16  2  2.78  2  2.59  2  1.44 20  2.74  8  0.95  2  2.69      7
# 1120 :         2.50 50  0.72  2  3.50  2  2.88  2  3.44  2  7.00  1  7.00  1  0.21   3
# 1120 :         Uave =   0.2380   Vave =   0.1176   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36676E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48452E-06 ppm      12.5186 %
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6737733E-02  3.6662292E-02 -3.8147736E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.691E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# Active file found in C:\Users\KWILKES\Desktop\PFAS_Modeling\cfs_para_test_cond\001_1stream\1120_41kW_CF4_port1. Starting monitoring and updating...
# ['SORMAX', 'INDRST', 'MAXIT', 'MAXITP']
#      2.5000     50   2000      0   !SORMAX,INDRST,MAXIT,MAXITP
#
# ['2.5000', '50', '2000', '0']
# ['2.5000', '50', '10', '0']
# Active file updated and monitoring completed in C:\Users\KWILKES\Desktop\PFAS_Modeling\cfs_para_test_cond\001_1stream\1120_41kW_CF4_port1. Exiting monitoring.
# 1120 :     5   7.00     3.14  2  2.77  2  2.57  2  1.43 20  2.64  8  0.94  2  2.67      9
# 1120 :         2.50 50  0.64  2  3.47  2  2.89  2  3.60  2  7.00  1  7.00  1  0.21   3
# 1120 :         Uave =   0.2379   Vave =   0.1176   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36675E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48454E-06 ppm      12.5195 %
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6737990E-02  3.6661901E-02 -3.8273584E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.680E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :     6   7.00     3.15  2  2.78  2  2.57  2  1.43 20  2.61  8  0.94  2  2.56      6
# 1120 :         2.50 50  0.60  2  3.52  2  2.89  2  3.44  2  7.00  1  7.00  1  0.21   3
# 1120 :         Uave =   0.2379   Vave =   0.1176   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36674E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48439E-06 ppm      12.5204 %
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6738385E-02  3.6661614E-02 -3.8467860E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.668E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :     7   7.00     3.14  2  2.77  2  2.56  2  1.41 20  2.63  8  0.94  2  2.46      7
# 1120 :         2.50 50  0.59  2  3.48  2  2.88  2  3.47  2  7.00  1  7.00  1  0.21   4
# 1120 :         Uave =   0.2378   Vave =   0.1175   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36674E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48442E-06 ppm      12.5214 %
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6738832E-02  3.6661521E-02 -3.8687943E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.657E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :     8   7.00     3.14  2  2.77  2  2.55  2  1.43 20  2.59  8  0.93  2  2.42      8
# 1120 :         2.50 50  0.62  2  3.53  2  2.87  2  3.40  2  7.00  1  7.00  1  0.21   3
# 1120 :         Uave =   0.2378   Vave =   0.1175   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36674E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48427E-06 ppm      12.5224 %
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6739040E-02  3.6661308E-02 -3.8790414E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.645E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :     9   7.00     3.15  2  2.79  2  2.59  2  1.47 20  2.74  8  0.93  2  2.31      5
# 1120 :         2.50 50  0.72  2  3.51  2  2.87  2  3.40  2  7.00  1  7.00  1  0.21   4
# 1120 :         Uave =   0.2378   Vave =   0.1175   Wave =   0.0317
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36673E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48439E-06 ppm      12.5234 %
# 1120 :  bcin: before extru
# 1120 :  BCIN:FLOWIN,TKEIN,TEDIN,ENTHIN,CHIIN,ETAIN,FMIXIN=  1.8700667E-02
# 1120 :   7.1543641E-04  1.7943049E-02  -5162.903      0.0000000E+00  0.0000000E+00
# 1120 :   7.4073597E-04
# 1120 :  bcin: after extru
# 1120 :  BCIN:FLOWIN,TKEIN,TEDIN,ENTHIN,CHIIN,ETAIN,FMIXIN=  3.6660567E-02
# 1120 :   1.9515149E-02  0.4894373      -140829.9      0.0000000E+00  0.0000000E+00
# 1120 :   2.0205252E-02
# 1120 :   BCOUT: FLOW, FLOWOUT, UVWINC =   3.6739096E-02  3.6661144E-02 -3.8817571E-03
# 1120 :
# 1120 :  Corrections off.  Suggest correcting fs by: -4.633E+00 % based on integral of f at outlet
# 1120 :  Corrections off.  Suggest correcting etas by:  0.000E+00 % based on integral of eta at outlet
# 1120 :    10   7.00     3.14  2  2.77  2  2.55  2  1.46 20  2.61  8  0.92  2  2.20     12
# 1120 :         2.50 50  0.63  2  3.52  2  2.88  2  3.56  2  7.00  1  7.00  1  0.21   4
# 1120 :         Uave =   0.2377   Vave =   0.1175   Wave =   0.0316
# 1120 :      Integrated Outlet Temp:    866.7 K,  Outlet Mass Flow:  0.36674E-01 kg/s
# 1120 :      Integrated Outlet CO (wet), O2:  0.48424E-06 ppm      12.5244 %
# 1120 :
# 1120 :  GAS PHASE NOT CONVERGED AFTER ITERATION NO.   10
# 1120 :
# 1120 :
# 1120 : GR_END
# 1120 : Writing Final Database and Restart Files
# 1120 :  Adiabatic Flame Temperature:    1205.280
# 1120 :  Adiabatic Flame Temp (w/HL):    1213.624
# 1120 :    Overall Equivalence Ratio:   0.3731023      (fuel rich when er > 1.0)
# 1120 :    Approximate Thermal Input:    38008.12      watts (at current burnout)
# 1120 :   Apprx Thermal Input (w/HL):    38397.29      watts (at current burnout)
# 1120 :
# 1120 :  Average eddy diffusivity =  6.033E-04
# 1120 :  Average Prandtl Mixing Length =  1.099E-02
# 1120 :  into RESTRT/final call
# 1120 :  out of RESTRT/final call
# 1120 :
# 1120 :
# 1120 :      TOTAL CPU TIME:   0 hours,  1 minutes,  5.460 seconds!
# 1120 :  TLEFT =     29.5%
# 1120 :  TRAD  =     20.9%
# 1120 :  TPROP =      1.8%
# 1120 :  TPRIN =      0.2%
# 1120 :  TPDE  =     24.2%          TPD  =  32.5% of TPDE
# 1120 :  TRSRT =     23.4%          TSOLV =  67.5% of TPDE
# 1120 :  TTABL =      0.0%
# 1120 :
# 1120 : GR_ALL_DONE
# 1120 :  qct, netwall, netexit    5759.407       7892.610      0.0000000E+00
# 1120 :  Returning from glacier
# 1120 : ERR: Glacier terminated normally
# 1120 :  patience:  reading......
# 1120 :  patience:  reading...function names...
# 1120 :  patience:  reading...geometry...
# 1120 :  patience:  reading...function values
# 1120 :  Now reading function            1
# 1120 :  Index for u-velocity =            1
# 1120 :
# 1120 :  Now reading function            2
# 1120 :  Index for v-velocity =            2
# 1120 :
# 1120 :  Now reading function            3
# 1120 :  Index for w-velocity =            3
# 1120 :
# 1120 :  Now reading function            4
# 1120 :  Now reading function            5
# 1120 :  Now reading function            6
# 1120 :  Index for tke =            6
# 1120 :
# 1120 :  Now reading function            7
# 1120 :  Index for ted =            7
# 1120 :
# 1120 :  Now reading function            8
# 1120 :  Now reading function            9
# 1120 :  Index for mix_frac =            9
# 1120 :
# 1120 :  Now reading function           10
# 1120 :  Now reading function           11
# 1120 :  Index for eta =           11
# 1120 :
# 1120 :  Now reading function           12
# 1120 :  Now reading function           13
# 1120 :  Now reading function           14
# 1120 :  Index for temperature =           14
# 1120 :
# 1120 :  Now reading function           15
# 1120 :  Now reading function           16
# 1120 :  Now reading function           17
# 1120 :  Now reading function           18
# 1120 :  Now reading function           19
# 1120 :  Now reading function           20
# 1120 :  Now reading function           21
# 1120 :  Now reading function           22
# 1120 :  Now reading function           23
# 1120 :  Now reading function           24
# 1120 :  Now reading function           25
# 1120 :  Now reading function           26
# 1120 :  Now reading function           27
# 1120 :  Now reading function           28
# 1120 :  Now reading function           29
# 1120 :  Now reading function           30
# 1120 :  Now reading function           31
# 1120 :  Now reading function           32
# 1120 :  Now reading function           33
# 1120 :  Now reading function           34
# 1120 :  Now reading function           35
# 1120 :  Now reading function           36
# 1120 :  Now reading function           37
# 1120 :  Now reading function           38
# 1120 :  Now reading function           39
# 1120 :  Now reading function           40
# 1120 :  Now reading function           41
# 1120 :  Now reading function           42
# 1120 :  Now reading function           43
# 1120 :  Now reading function           44
# 1120 :  Now reading function           45
# 1120 :  Now reading function           46
# 1120 :  Now reading function           47
# 1120 :  Now reading function           48
# 1120 :  Now reading function           49
# 1120 :  Now reading function           50
# 1120 :  Now reading function           51
# 1120 :  Now reading function           52
# 1120 :  Now reading function           53
# 1120 :  Now reading function           54
# 1120 :  Now reading function           55
# 1120 :  Now reading function           56
# 1120 :  Now reading function           57
# 1120 :
# 1120 :  Starting integration
# 1120 :
# 1120 :  LSSF  T
# 1120 :  Point:            1
# 1120 :  Hit wall or exited at x,y,z,=
# 1120 :    4.502492      5.1049232E-03  1.2879974E-02
# 1120 :  after       438029  timesteps.
# 1120 :  Elapsed time =    15.00022      seconds.
# 1120 :
# 1120 :  patience:  reading......
# 1120 :  patience:  reading...function names...
# 1120 :  patience:  reading...geometry...
# 1120 :  patience:  reading...function values
# 1120 :  Now reading function            1
# 1120 :  Index for u-velocity =            1
# 1120 :
# 1120 :  Now reading function            2
# 1120 :  Index for v-velocity =            2
# 1120 :
# 1120 :  Now reading function            3
# 1120 :  Index for w-velocity =            3
# 1120 :
# 1120 :  Now reading function            4
# 1120 :  Now reading function            5
# 1120 :  Now reading function            6
# 1120 :  Index for tke =            6
# 1120 :
# 1120 :  Now reading function            7
# 1120 :  Index for ted =            7
# 1120 :
# 1120 :  Now reading function            8
# 1120 :  Now reading function            9
# 1120 :  Index for mix_frac =            9
# 1120 :
# 1120 :  Now reading function           10
# 1120 :  Now reading function           11
# 1120 :  Index for eta =           11
# 1120 :
# 1120 :  Now reading function           12
# 1120 :  Now reading function           13
# 1120 :  Now reading function           14
# 1120 :  Index for temperature =           14
# 1120 :
# 1120 :  Now reading function           15
# 1120 :  Now reading function           16
# 1120 :  Now reading function           17
# 1120 :  Now reading function           18
# 1120 :  Now reading function           19
# 1120 :  Now reading function           20
# 1120 :  Now reading function           21
# 1120 :  Now reading function           22
# 1120 :  Now reading function           23
# 1120 :  Now reading function           24
# 1120 :  Now reading function           25
# 1120 :  Now reading function           26
# 1120 :  Now reading function           27
# 1120 :  Now reading function           28
# 1120 :  Now reading function           29
# 1120 :  Now reading function           30
# 1120 :  Now reading function           31
# 1120 :  Now reading function           32
# 1120 :  Now reading function           33
# 1120 :  Now reading function           34
# 1120 :  Now reading function           35
# 1120 :  Now reading function           36
# 1120 :  Now reading function           37
# 1120 :  Now reading function           38
# 1120 :  Now reading function           39
# 1120 :  Now reading function           40
# 1120 :  Now reading function           41
# 1120 :  Now reading function           42
# 1120 :  Now reading function           43
# 1120 :  Now reading function           44
# 1120 :  Now reading function           45
# 1120 :  Now reading function           46
# 1120 :  Now reading function           47
# 1120 :  Now reading function           48
# 1120 :  Now reading function           49
# 1120 :  Now reading function           50
# 1120 :  Now reading function           51
# 1120 :  Now reading function           52
# 1120 :  Now reading function           53
# 1120 :  Now reading function           54
# 1120 :  Now reading function           55
# 1120 :  Now reading function           56
# 1120 :  Now reading function           57
# 1120 :
# 1120 :  Starting integration
# 1120 :
# 1120 :  LSSF  T
# 1120 :  Point:            1
# 1120 :  Hit wall or exited at x,y,z,=
# 1120 :   6.3697174E-02   2.802156     -8.4069213E-03
# 1120 :  after        20647  timesteps.
# 1120 :  Elapsed time =    5.189062      seconds.
# 1120 :
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Kinetics.inp......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Thermo.dat......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Kinetics.inp......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Thermo.dat......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Kinetics.inp......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Thermo.dat......
# 1120 : C2H6
# 1120 : C2HF
# 1120 : C2JLMF2
# 1120 : C3H8
# 1120 : CF3CF3
# 1120 : CF4
# 1120 : CH2CF2
# 1120 : CH2CHF
# 1120 : CH2F2
# 1120 : CH2FCF3
# 1120 : CH2FCH2F
# 1120 : CH2FCHF2
# 1120 : CH3CF3
# 1120 : CH3CH2F
# 1120 : CH3CHF2
# 1120 : CH3F
# 1120 : CH4
# 1120 : CHF2CF3
# 1120 : CHF2CHF2
# 1120 : CHF3
# 1120 : CHFCF2
# 1120 : CHFCHF[Z]
# 1120 : CO2
# 1120 : H2O
# 1120 : N2
# 1120 : O2
# 1120 : nCF3CHCH2
# 1120 : nCH2CFCF3
# 1120 : nCHFCHCF3
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Kinetics.inp......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Thermo.dat......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Kinetics.inp......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Thermo.dat......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Kinetics.inp......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Thermo.dat......
# 1120 : Error! Input file line number: 10
# 1120 : Reactant: C2JLMF2 Not found in the thermo database!
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Kinetics.inp......
# 1120 : Parsing file C:\Users\KWILKES\AppData\Local\Programs\ReactionEngineeringInternational\CFS-EPA/Packages/Incinerators/Modules/Data/chem/NCSU_PFASmech1.0_Thermo.dat......
# 1120 : ERROR: UNABLE TO OPEN CUSTOM PROFILE FILE:
# RainbowBatch.exe C:/Users/KWILKES/Desktop/PFAS_Modeling/cfs_para_test_cond/001_1stream/0000_docs/1120_rainbow_41kW_CF4_port1.netj failed with return code 1.
